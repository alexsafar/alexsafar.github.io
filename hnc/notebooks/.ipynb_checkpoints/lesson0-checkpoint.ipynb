# %% [markdown]
# # Lesson 0 - Introduction to Python
#
# Experiment with this file. Go through each cell and change some values so that you understand what it's doing.
#
# --------
#
# #### Basic Coding Ideas:
# * You can assign a value to a variable in the following way:
# ```
# a = 3
# ```
# This will give the variable `a` the value `3`, which can then be used in future calculations such as:
# ```
# print(a + 3)
# ```
# which would return `6`.
#
#
# * Unlike many other programming languages such as Visual Basic, there is no need to declare variables to have a certain *type* in Python. Python will automatically figure out whether you are specifying an integer, a real number or a string (if it's in quotes). You can check the *type* of a variable with
# ```
# type(a)
# ```
# Variables can be named any combination of letters and numbers both lower case and upper case but must start with a letter. Python is case sensitive, so `A` is not the same as `a`!
#
#
# * Comments in Python are achieved with a `#` character. This means that anything written after the `#` in a line will be ignored. You should always write comments explaining what complicated lines do and write code in a coherent way. This is not exclusive to your code being readable by someone else either - if you write a code that is not properly commented and don’t look at it for a few months, you will not have any idea what it does the next time you look at it! This has happened to me so many times that I am determined to not let you make that mistake.
#
# ```
# print('Hello World') #This is a comment
# ```
#
#
# * **Indentation** in Python is **crucial**. These two code pieces are not the same, and in fact the second one will give a syntax error:
#
# ```
# for j in range(1,10):
#     print(j)
#
#
# for j in range(1,10):
# print(j)
# ```
#
# --------
#
# * If there is nothing else you take from this document, let the thing you learn be how to use **for loops** and **if statements**. These are central to most programs you will write during this course and usually play an important role in many other programs. The very simple example below illustrates what these statements do:
#
# ```
# for j in range(1,10):
#     print(j) #display j at each point in the loop
#
# for j in range(1,10):
#     if j == 5 or j == 7
#         print(j) # will only print 5 and 7
#
# ```
# --------
#
# #### Notes:
# * To run a cell, press Shift+Enter or go to Cell -> Run Cells.
#
#
# * Ask questions! Ask each other, ask me, ask Google. Read the error prompts - they are usually helpful!!
#
#
# * Finally, there is more than one way to write a program! People have styles, as you’ll begin to see soon. If your program is different to mine then that’s not a problem - you will develop your own way of doing things, your own way of naming things and as long as you’re consistent with yourself then it won’t matter. Someone once described it to me as learning a language, but with an accent - we can all understand each other but we say things in a slightly different way! It’s like that with programming, don’t be worried if your program looks different - if the results are the same it won’t matter too much.

# %%
print('Hello World!')

# %%
#simple arithmetic
2 + 3

# %%
#assign value to variable a, then do stuff to it
a = 2
print(a + 4)
print(a * 6)
print(a * a)

# %%
#assign a variable, reassign it and print
a = 3
a = a + 1 #a += 1 does the same thing here
print(a)

# %%
#loop through some range
for j in range(1,10): #note that "range" goes from 1 to 9 here
    print(j)

# %%
#add a conditional 'if' statement to a loop
for j in range(1,10):
    if j == 5 or j == 7: #note the double == (asks is j=5? if yes, print j)
        print(j)

# %%
#manipulating strings using + 
firstname = "Scott"
lastname = "Morgan"
print(firstname)
print(lastname)
print(firstname + " " + lastname) #note the space in the middle

# %%
#debugging exercise - find and fix all errors/bugs!
for k in range(1,10)
k += 1 #adds one to the current value of k
if k = 6:
    print("k = ")
    print(k)

# %% [markdown]
# #### Debugging exercise solution:
#
# Output should be exactly:
#
# ```
# k =
# 6
# ```
